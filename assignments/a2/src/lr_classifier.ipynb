# %%
import os
import cv2
import numpy as np
from joblib import dump, load
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from tensorflow.keras.datasets import cifar10
# Out:
# 2024-05-23 14:12:17.004709: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-23 14:12:17.579233: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-23 14:12:17.991318: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-23 14:13:03.177830: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /work/VisualAnalytics/cds-vis/assignments/a2/src/lr_classifier.ipynb Cell 1 line 7
#       <a href='vscode-notebook-cell://app-5051865-0.cloud.sdu.dk/work/VisualAnalytics/cds-vis/assignments/a2/src/lr_classifier.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> from sklearn.metrics import classification_report
#       <a href='vscode-notebook-cell://app-5051865-0.cloud.sdu.dk/work/VisualAnalytics/cds-vis/assignments/a2/src/lr_classifier.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> from sklearn.linear_model import LogisticRegression
# ----> <a href='vscode-notebook-cell://app-5051865-0.cloud.sdu.dk/work/VisualAnalytics/cds-vis/assignments/a2/src/lr_classifier.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> from tensorflow.keras.datasets import cifar10
#
# File /work/VisualAnalytics/cds-vis/assignments/a2/.venv/lib/python3.10/site-packages/tensorflow/__init__.py:462
#     460     importlib.import_module("tf_keras.src.optimizers")
#     461   else:
# --> 462     importlib.import_module("keras.src.optimizers")
#     463 except (ImportError, AttributeError):
#     464   pass
#
# File /usr/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /work/VisualAnalytics/cds-vis/assignments/a2/.venv/lib/python3.10/site-packages/keras/__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import _tf_keras
#       9 from keras import activations
#      10 from keras import applications
#
# File /work/VisualAnalytics/cds-vis/assignments/a2/.venv/lib/python3.10/site-packages/keras/_tf_keras/__init__.py:1
# ----> 1 from keras._tf_keras import keras
#
# File /work/VisualAnalytics/cds-vis/assignments/a2/.venv/lib/python3.10/site-packages/keras/_tf_keras/keras/__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import activations
#       9 from keras import applications
#      10 from keras import callbacks
#
# File /work/VisualAnalytics/cds-vis/assignments/a2/.venv/lib/python3.10/site-packages/keras/activations/__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.src.activations import deserialize
#       9 from keras.src.activations import get
#      10 from keras.src.activations import serialize
#
# File /work/VisualAnalytics/cds-vis/assignments/a2/.venv/lib/python3.10/site-packages/keras/src/__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File /work/VisualAnalytics/cds-vis/assignments/a2/.venv/lib/python3.10/site-packages/keras/src/activations/__init__.py:22
#      20 from keras.src.activations.activations import tanh
#      21 from keras.src.api_export import keras_export
# ---> 22 from keras.src.saving import object_registration
#      23 from keras.src.saving import serialization_lib
#      25 ALL_OBJECTS = {
#      26     relu,
#      27     leaky_relu,
#    (...)
#      43     log_softmax,
#      44 }
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:879, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:975, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1074, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
def convert_to_grayscale(img):
    return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
def normalize_img_data(img):
    return cv2.normalize(img, img, 0, 1.0, cv2.NORM_MINMAX)

# %%
def preprocess_images(images):
    processed_img_out = []
    for image in images:
        processed_img_out.append(normalize_img_data(convert_to_grayscale(image)))
    return np.array(processed_img_out).reshape(-1, 1024)

# %%
X_train_processed = preprocess_images(X_train)
X_test_processed = preprocess_images(X_test)
y_train_processed = y_train.flatten() 
y_test_processed = y_test.flatten()

# %%
img_labels = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

# %%
clf = LogisticRegression(random_state=42, max_iter=1000).fit(X_train_processed, y_train_processed)

# %%
dump(clf, "lr_classifier.joblib")
# Out:
# ['lr_classifier.joblib']

# %%
y_pred = clf.predict(X_test_processed)

# %%
with open("../out/lrc_report.txt", "w") as file:
        file.write(classification_report(y_test_processed, y_pred, target_names=img_labels))
